# %% [markdown]
# # Optimizing delivery with Reinforcement Learning

# %%
# Base Data Science snippet
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import time
from tqdm import tqdm_notebook

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Environment definition
# As for any RL problem, an environment must be designed where the Agent will evolve.<br>
# For convenience and readability, we will define it like OpenAI Gym environments

# %%
import sys
sys.path.append("../")
from delivery import *

# %%
env = DeliveryEnvironment()
# Out:
# Initialized Delivery Environment with 10 random stops
# Target metric for optimization is distance

# %%
env.stops
# Out:
# [6]

# %%
for i in [0,1,2,3]:
    env.step(i)

# %%
env.render()

# %% [markdown]
# # Q Learning

# %%
import sys
sys.path.append("../")

from delivery import run_episode,DeliveryQAgent,run_n_episodes

# %% [markdown]
# ## Simple case

# %%
env = DeliveryEnvironment(method = "distance")
# Out:
# Initialized Delivery Environment with 10 random stops
# Target metric for optimization is distance

# %%
agent = DeliveryQAgent(env.observation_space,env.action_space)

# %%
run_n_episodes(env,agent,"training_10_stops.gif")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18028/3649065235.py in <module>
# ----> 1 run_n_episodes(env,agent,"training_10_stops.gif")
#
# ~\OneDrive\Uni\K3\SWMAL\O4\TSP\TSP-RL\delivery.py in run_n_episodes(env, agent, name, n_episodes, render_each, fps)
#     437
#     438     # Experience replay
# --> 439     for i in tqdm_notebook(range(n_episodes)):
#     440
#     441         # Run the episode
#
# ~\anaconda3\envs\spyder\lib\site-packages\tqdm\__init__.py in tqdm_notebook(*args, **kwargs)
#      26          "Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`",
#      27          TqdmDeprecationWarning, stacklevel=2)
# ---> 28     return _tqdm_notebook(*args, **kwargs)
#      29
#      30
#
# ~\anaconda3\envs\spyder\lib\site-packages\tqdm\notebook.py in __init__(self, *args, **kwargs)
#     240         unit_scale = 1 if self.unit_scale is True else self.unit_scale or 1
#     241         total = self.total * unit_scale if self.total else self.total
# --> 242         self.container = self.status_printer(self.fp, total, self.desc, self.ncols)
#     243         self.container.pbar = proxy(self)
#     244         self.displayed = False
#
# ~\anaconda3\envs\spyder\lib\site-packages\tqdm\notebook.py in status_printer(_, total, desc, ncols)
#     116         # Prepare IPython progress bar
#     117         if IProgress is None:  # #187 #451 #558 #872
# --> 118             raise ImportError(WARN_NOIPYW)
#     119         if total:
#     120             pbar = IProgress(min=0, max=total)
#
# ImportError: IProgress not found. Please update jupyter and ipywidgets. See https://ipywidgets.readthedocs.io/en/stable/user_install.html

# %% [markdown]
# ## Final enviroment:

# %%
env.render()

# %%
test = load_addresses("addresses.csv")

# %%
test
# Out:
#    id                               full_address
# 0   1  Palle Juul-Jensens Blvd. 99,  8200 Aarhus
# 1   2         Thit Jensens Gade 20,  8000 Aarhus
# 2   3            grumstolsvej 4d,  8270 højbjerg
# 3   4           Søren Frichsvej 52,  8230 Åbyhøj
# 4   5              Kalendervej 9,  8210 Aarhus V
# 5   6     Hack Kampmanns Plads 2,  8000 Aarhus C
# 6   7           Hans Egedes Vej 21,  8200 Aarhus
# 7   8                 Filmbyen 4,  8000 Aarhus C
# 8   9           Nordre Ringgade 1, 8000 Aarhus C
# 9  10         Katrinebjergvej 81,  8200 Aarhus N
